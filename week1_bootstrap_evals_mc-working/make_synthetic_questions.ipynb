# %% [markdown]
# # Goal
#
# This notebook shows how to make synthetic data to bootstrap evaluation of your retrieval system.
#
# This synthetic data contains many triplets of `(RAG system input, system output, desired chunk to retrieve)`. For this example, we will work on a hardware retailer's system to answer user questions based on existing product previous. So the synthetic data will look like
#
# ```
# Q: How frequently do I need to replace the blades on this saw?
# A: A customer reported getting 7-10 hours of active use between blade replacements.
# Chunk ID: 3
# ```
#
# Once you have many of these triplets, you can experiments with different retrieval strategies (e.g. different embedding models, embedding vs keyword search, etc) to determine which strategies most consistently retrieve the desired chunks.
#
# # A Starting Point
#
# A simple approach would follow pseudo code:
#
# ```
# synth_data = []
# for chunk in corpus:
#     response = call_llm(f"Give me a JSON array of 10 question/answer pairs. The questions should be things someone might ask about a product before purchase. The answer should be something contained in this text: {chunk}")
#     q_a = json.loads(response.content)
#     q_a_c = [{'question': q, 'answer': a, 'chunk': chunk} for (q, a) in q_a_pairs]
#     synth_data.extend(q_a_c)
# ```
#
# A practical implementation should address three issues that arise in the naive pseudo code.
#
# | Issue | Solution |
# |---------|----------|
# | Inconsistent formatting of LLM response (e.g. different keys) | Instructor library |
# | Bad questions | Guidance/examples in prompt |
# | Time waiting for LLM responses when iterating over many chunks | Async LLM calls|
#
# # Reusable Code to Bootstrap Evals
#
# The code in this notebook addresses these issues. The code is also available as [this script](https://gist.github.com/jxnl/5627c9d463ffe0b085896f7890fab1bf).
#
# ## Data
#
# This course uses synthetic data based on the use-case of answering questions on a hardware retailer's website based on product reviews. We have created this data in `make_product_reviews.ipynb`. Here is a small sample of the data.

# %%
import lancedb
import pandas as pd

pd.set_option("display.max_colwidth", 160)

db = lancedb.connect("./lancedb")
reviews_table = db.open_table("reviews")
sample_reviews = reviews_table.to_pandas()
sample_reviews.review
# Out:
# 0     I recently bought the High-Speed Drill Bit Set and am thoroughly impressed. These bits cut through wood, metal, and plastic like a hot knife through butter....
# 1     This drill bit set is a game-changer! The bits are sharp and perfect for my woodworking projects. I was able to drill precise holes in oak and pine without ...
# 2     I've used many drill bit sets over the years, but this High-Speed Drill Bit Set stands out. The 15 professional-grade bits have handled everything from dril...
# 3     As a professional contractor, I need reliable tools, and this drill bit set does not disappoint. The set includes every size I need, and they all perform ex...
# 4     My home renovation project has been a breeze thanks to this High-Speed Drill Bit Set. I’ve used it on wood, plastic, and even some metal fixtures, and it pe...
# 5     I purchased this drill bit set for my hobby of building custom furniture, and it has been fantastic. The bits cut through hardwood like maple and walnut eff...
# 6     The High-Speed Drill Bit Set exceeded my expectations. The bits are made from high-quality steel and haven't shown any signs of wear. I've used them on vari...
# 7     This drill bit set offers great value for the money. The bits are incredibly sharp and durable. I've drilled hundreds of holes in different materials withou...
# 8     After using this High-Speed Drill Bit Set for several weeks, I can confidently say it's one of the best I've ever owned. The bits are sharp and maintain the...
# 9     I am very impressed with the performance of this drill bit set. The bits drill smoothly through both soft and hard materials without any slipping. The premi...
# 10    I've been using this high-speed drill bit set for my DIY projects and it has exceeded my expectations. The 20 bits cover all the sizes I need, and they're p...
# 11    As a professional contractor, I can say this drill bit set is top-notch. The bits cut through metal like butter and maintain their sharpness, even after mul...
# 12    This drill bit set is a lifesaver for my home renovation projects. The bits are extremely sharp and glide through different materials without a hitch. The r...
# 13    I purchased this drill bit set for some woodworking and I am very happy with it. The bits are incredibly sharp and stay that way even after multiple uses. T...
# 14    These high-speed drill bits are fantastic! I’ve used them to drill through ceramic tiles, metal sheets, and hardwood, and they perform excellently every tim...
# 15    I've tried many drill bit sets over the years and this one stands out. The quality of these bits is exceptional, and they come in all the sizes I need for v...
# 16    Having used these drill bits for several months now, I can confidently say they're some of the best on the market. The bits cut smoothly and the material do...
# 17    The high-speed drill bit set delivers exactly what it promises. I've used the bits on metal, wood, and even stone, and they perform exceptionally. The bits ...
# 18    These drill bits are amazing. I work with different materials all the time, and this set handles everything from softwood to hardened steel. The reduced fri...
# 19    I bought this set for my husband and he absolutely loves it. He says the bits are very sharp and cut through material with ease. The heat reduction feature ...
# 20    I've been using this High-Speed Drill Bit Set for about six months now, and it has exceeded all my expectations. The variety of sizes included caters to all...
# 21    This drill bit set is phenomenal! The bits are precision-engineered, as advertised, and they cut through materials like butter. I've used them on various pr...
# 22    High-Speed Drill Bit Set is a game-changer for anyone serious about their DIY projects. I've drilled through everything from thick oak to hardened steel wit...
# 23    Absolutely love this drill bit set! Ideal for both professionals and home DIY enthusiasts. The precision-engineered bits provide smooth and accurate drillin...
# 24    As a contractor, I go through a lot of drill bits, but this set has really stood out. The drill bits are high-quality and remain sharp even after multiple p...
# 25    The best drill bit set I have ever purchased! These bits drill faster and cleaner than any other bits I have used in the past. I appreciate the variety of s...
# 26    This High-Speed Drill Bit Set is a must-have for any toolbox. The bits drill with precision and speed – just as advertised. I've used them on both wood and ...
# 27    These drill bits are top-notch. The precision engineering shines through on each use; I've been able to drill into tough materials with ease. The set includ...
# 28    Amazing drill bit set! I’ve used these on several projects, ranging from building furniture to repairing fences. They effortlessly cut through both wood and...
# 29    I've tried many drill bit sets over the years, but this High-Speed Drill Bit Set is by far the best. The bits offer incredible accuracy and speed, making my...
# 30    I've been using this portable router for the past 6 months and it's been fantastic for my woodworking projects. The lightweight design ensures that my hand ...
# 31    As a professional carpenter, the precision this router offers is top notch. I specifically love the edge trimming capabilities – it’s very clean and smooth....
# 32    I am just an amateur woodworker, but this router has made a big difference. It's light enough for me to handle without fatigue, and the variable speeds mean...
# 33    Bought this router mainly for its portability and I am impressed. It fits nicely in my tool bag and isn’t cumbersome to carry around at all. Despite its siz...
# 34    This is my go-to tool for any woodworking detail work now. Weighing in at just under 5 lbs, it’s easy on the wrists, and the ergonomic grip ensures comfort ...
# 35    I love the versatility of this portable router. I've used it for everything from cabinetry to creating intricate designs in hardwood panels. The ability to ...
# 36    This router exceeded my expectations. For a lightweight tool, it provides exceptional power. Whether I'm hollowing out grooves or trimming edges, the result...
# 37    I'm a hobbyist woodworker and this router has become essential to my toolkit. It’s incredibly easy to maneuver even for a beginner. The different speed sett...
# 38    The portability of this router is what sold me. Setting up is quick and simple, and the lightweight design means my hand doesn’t tire easily. It does an exc...
# 39    As someone who works on-site often, having a reliable and portable router is crucial. This one doesn't disappoint. It’s compact yet powerful, making quick w...
# 40    I purchased this portable router a month ago, and it's been a game-changer. The compact design makes it easy to maneuver, even in tight spaces. The motor is...
# 41    This portable router is amazing! The motor runs smoothly and provides consistent performance. I love the easy-to-use depth adjustment; it makes getting the ...
# 42    I've been using this portable router for about six months now. The motor is really powerful, and it handles all my woodworking tasks effortlessly. The depth...
# 43    As a professional woodworker, I’ve worked with numerous routers, but this portable router stands out. The motor is extremely reliable and powerful. The dept...
# 44    I bought this portable router for a few DIY projects around the house. It has exceeded my expectations! The motor is strong and maintains its performance wi...
# 45    This portable router has quickly become my go-to tool for any edging or shaping tasks. The compact design is perfect for handheld operation, and the motor p...
# 46    I recently added this portable router to my woodworking toolkit, and I’m impressed. It’s compact, which makes it easy to handle, but it’s also packed with a...
# 47    What a fantastic tool! This portable router has a powerful motor that delivers consistent performance every time. The depth adjustment feature is easy to us...
# 48    The portable router is a solid investment for any woodworker. The motor is powerful and handles heavy tasks with ease. The depth adjustment feature is incre...
# 49    Absolutely love this portable router! The motor is very powerful and consistent, handling all my shaping and edging tasks with ease. The depth adjustment al...
# 50    I've been using this portable router for the past six months, and it has significantly improved my woodworking projects. The soft start feature is fantastic...
# 51    This is the best portable router I have ever owned. The machine is powerful yet operates quietly, thanks to the efficient motor design. The soft grip handle...
# 52    Purchased this portable router a year ago, and it has exceeded all my expectations. The build quality is sturdy and it feels very durable. The soft start fu...
# 53    I've been into woodworking for over a decade, and this portable router is one of the best tools I've ever used. The soft start feature prevents the tool fro...
# 54    This portable router was a great investment. I was initially drawn to it because of the soft start feature, and it hasn't disappointed. The reduction in tor...
# 55    A fantastic portable router for any woodworking enthusiast! The soft start function ensures a smooth operation, reducing wear and tear on the motor. The qua...
# 56    I recently purchased this portable router and couldn't be happier with it. The soft start feature offers better control and lessens initial torque, making t...
# 57    This portable router is a workhorse! The soft start feature makes all the difference, reducing startup torque and making it safer to use. I appreciate how w...
# 58    As an avid DIYer, this portable router has quickly become one of my favorite tools. The soft start feature minimizes torque, making the operation smoother a...
# 59    Top-notch portable router! I've utilized it for several woodworking projects over the past few months, and it has consistently delivered excellent results. ...
# Name: review, dtype: object

# %% [markdown]
# ## Structure The Data
#
# We use Pydantic & Instructor for a reliable interface between our LLMs and the structured data formats we need to run code on LLM output

# %%
from pydantic import BaseModel


class Review(BaseModel):
    id: str
    product_title: str
    product_description: str
    review: str


sample_chunks = [
    Review(
        id=str(row.id),
        product_title=row.product_title,
        product_description=row.product_description,
        review=row.review,
    )
    for _, row in sample_reviews.iterrows()
]

n_questions = 2  # number of questions to get in each LLM call
example_questions = [
    "What does the reviewer like about the product?",
    "What does the reviewer think could be improved?",
]

# %% [markdown]
# Now see how we build questions on a single chunk

# %%
from typing import List
import instructor
from openai import AsyncOpenAI

# Patch the AsyncOpenAI client
client = instructor.from_openai(AsyncOpenAI())


class QuestionAnswer(BaseModel):
    question: str
    answer: str


class ChunkEval(QuestionAnswer):
    chunk_id: str


async def generate_evals(
    review: Review, n_questions: int, example_questions: List[str]
) -> List[ChunkEval]:

    prompt = f"""
        Generate `{n_questions}` question-answer pairs about a {review.product_title}. The answers should primarily be derived from information in this product review:

        <content>
        {review.review}
        </content>

        While they should contain information from the product review, you may also find it helpful context to see a product description:
        <content>
        {review.product_description}
        </content>

        Example questions:
        {chr(10).join(f'- {q}' for q in example_questions)}

        Provide a concise and specific answer for each question.
        Do not use the exact example questions. Use them only as inspiration for the types of more specific questions to generate.
        Do not include answers that are not in the content.
        Questions should ask about product characteristics (e.g. durability) and answers should refer to product characteristics without referring to the reviewer specifically.
        Stylistically, the questions should resemble what people would ask a RAG-based answer bot on a retailer's website. So they can be a little informal, messy or scattered.
        """

    try:
        pairs = client.chat.completions.create_iterable(
            model="gpt-4o-mini",
            response_model=QuestionAnswer,
            messages=[{"role": "user", "content": prompt}],
        )
        return [
            ChunkEval(question=pair.question, answer=pair.answer, chunk_id=review.id)
            async for pair in pairs
        ]
    except Exception as e:
        print(f"Error generating evals: {str(e)}")
        return []


first_chunk_res = await generate_evals(sample_chunks[0], n_questions, example_questions)
first_chunk_res
# Out:
# [ChunkEval(question='How well do these bits perform when drilling through tough materials?', answer='The bits cut through wood, metal, and plastic very effectively, and the 7mm bit performed flawlessly even when drilling through a thick steel plate.', chunk_id='0'),
#  ChunkEval(question='What makes the High-Speed Drill Bit Set durable?', answer='These bits are made from premium steel construction, which feels incredibly durable and has shown no wear after multiple uses.', chunk_id='0')]

# %% [markdown]
# To run `generate_evals` for many chunks in parallel, wrap it with a function that also takes a semaphore.

# %%
import asyncio


class ChunkProcessingError(Exception):
    pass


async def process_chunk(
    review: Review,
    n_questions: int,
    example_questions: List[str],
    semaphore: asyncio.Semaphore,
) -> List[ChunkEval]:
    async with semaphore:
        try:
            return await generate_evals(review, n_questions, example_questions)
        except Exception as e:
            print(f"Unexpected error processing chunk {review.id}: {str(e)}")
            raise ChunkProcessingError(f"Failed to process chunk {review.id}") from e


# Test that we get the same results as directly calling generate_evals
await process_chunk(
    sample_chunks[0], n_questions, example_questions, asyncio.Semaphore(1)
)
# Out:
# [ChunkEval(question='How well do the bits cut through different materials?', answer='The bits cut through wood, metal, and plastic like a hot knife through butter.', chunk_id='0'),
#  ChunkEval(question='What sets apart the durability of these bits?', answer="The bits are made from premium steel construction, which feels incredibly durable and hasn't shown any wear after multiple uses.", chunk_id='0')]

# %% [markdown]
# Now you can call `process_chunks` with all chunks to build the full dataset

# %%
import json


async def create_synthetic_dataset(
    reviews: List[Review],
    n_questions: int,
    example_questions: List[str],
    max_concurrency: int = 10,
) -> List[ChunkEval]:
    semaphore = asyncio.Semaphore(max_concurrency)
    tasks = [
        process_chunk(review, n_questions, example_questions, semaphore)
        for review in reviews
    ]
    results = await asyncio.gather(*tasks, return_exceptions=True)

    dataset = []
    for result in results:
        if isinstance(result, ChunkProcessingError):
            print(result)
        elif isinstance(result, list):
            dataset.extend(result)
        else:
            print(f"Unexpected result type: {type(result)}")

    return dataset


def save_dataset(dataset: List[ChunkEval], filename: str):
    with open(filename, "w") as f:
        json.dump([chunk_eval.model_dump() for chunk_eval in dataset], f, indent=2)


synthetic_dataset = await create_synthetic_dataset(
    sample_chunks, n_questions, example_questions
)
save_dataset(synthetic_dataset, "synthetic_eval_dataset.json")

print(f"Generated {len(synthetic_dataset)} ChunkEvals.")
print("Dataset saved as 'synthetic_eval_dataset.json'")
# Out:
# Generated 120 ChunkEvals.
# Dataset saved as 'synthetic_eval_dataset.json'

# %% [markdown]
# View the data as a DataFrame

# %%
data = [(i.question, i.answer, i.chunk_id) for i in synthetic_dataset]
pd.DataFrame(data, columns=["question", "answer", "chunk_id"]).head()
# Out:
#                                                                        question  \
# 0                  How well do these drill bits perform on different materials?
# 1                    What is the quality of the construction of the drill bits?
# 2               How good are the bits for drilling through different materials?
# 3                 What’s the deal with the carrying case in this drill bit set?
# 4  How many bits are in the High-Speed Drill Bit Set and what are they made of?
#
#                                                                                                                 answer  \
# 0                                     These bits cut through wood, metal, and plastic like a hot knife through butter.
# 1  The drill bits are made from premium steel, offering incredible durability and showing no wear after multiple uses.
# 2    The bits work great for drilling precise holes in both wood (like oak and pine) and plastic without getting dull.
# 3         The carrying case is well-organized, making it easy to find the right bit quickly for storage and transport.
# 4                            The High-Speed Drill Bit Set includes 15 professional-grade bits made from premium steel.
#
#   chunk_id
# 0        0
# 1        0
# 2        1
# 3        1
# 4        2
